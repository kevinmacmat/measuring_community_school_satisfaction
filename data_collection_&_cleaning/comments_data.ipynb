# %%
import pandas as pd
from

# %%
no_comment_df = pd.read_csv('/Users/kevinmacmat/Documents/flatiron/module_projects/capstone/csv/sqr_no_comments.csv')

# %%
no_comment_df.shape
# Out:
# (1076, 40)

# %%
no_comment_df.dbn
# Out:
# 0       01M015
# 1       01M019
# 2       01M020
# 3       01M034
# 4       01M063
#          ...
# 1071    32K377
# 1072    32K383
# 1073    32K384
# 1074    32K554
# 1075    32K562
# Name: dbn, Length: 1076, dtype: object

# %%
no_comment_df.tail()
# Out:
#          dbn                                    school_name school_type  \
# 1071  32K377             P.S. 377 Alejandrina B. De Gautier  Elementary
# 1072  32K383                   J.H.S. 383 Philippa Schuyler      Middle
# 1073  32K384               P.S. /I.S. 384 Frances E. Carter         K-8
# 1074  32K554           All City Leadership Secondary School      Middle
# 1075  32K562  Evergreen Middle School for Urban Exploration      Middle
#
#       enrollment  rigor_instruction_rating  collab_teachers_rating  \
# 1071         135                      0.50                    0.75
# 1072         909                      0.75                    0.50
# 1073         476                      0.75                    0.75
# 1074         180                      1.00                    1.00
# 1075         370                      1.00                    0.75
#
#       support_environ_rating  effective_lead_rating  fam_comm_ties_rating  \
# ...

# %%
concat_comments = pd.read_csv('/Users/kevinmacmat/Documents/flatiron/module_projects/capstone/csv/batch_scraped_csv/batch_0-100_comments.csv')

# %%
concat_comments
# Out:
#        dbn                                           comments
# 0   01M015  ['P.S. 15 is an extraordinary small school tha...
# 1   01M019  ['Wrong person', "The negative comments don't ...
# 2   01M020  ['While we have always lived with the notion t...
# 3   01M034  ['The DOE has tabled a proposal to combine PS ...
# 4   01M063  ["This school is an amazing school because we ...
# ..     ...                                                ...
# 95  03M258  ['I started at this school when it first start...
# 96  03M291  ['Do not go to this school, especially if you ...
# 97  03M333  ["now people can say what they want about clai...
# 98  03M334  ['https://ny.chalkbeat.org/2020/4/23/21233687/...
# 99  03M415  ['I am a new parent to Wadleigh Secondary Scho...
#
# [100 rows x 2 columns]

# %%
prev_df = pd.read_csv('/Users/kevinmacmat/Documents/flatiron/module_projects/capstone/csv/sqr_&_comments.csv')

# %%
prev_df.shape
# Out:
# (985, 41)

# %%
prev_df.head()
# Out:
#       dbn                     school_name school_type  enrollment  \
# 0  01M015       P.S. 015 Roberto Clemente  Elementary         161
# 1  01M019             P.S. 019 Asher Levy  Elementary         239
# 2  01M020            P.S. 020 Anna Silver  Elementary         439
# 3  01M034  P.S. 034 Franklin D. Roosevelt         K-8         288
# 4  01M063       The STAR Academy - P.S.63  Elementary         207
#
#    rigor_instruction_rating  collab_teachers_rating  support_environ_rating  \
# 0                      1.00                     1.0                    1.00
# 1                      1.00                     1.0                    0.75
# 2                      0.25                     0.5                    0.50
# 3                      0.50                     0.5                    0.50
# 4                      1.00                     1.0                    0.75
#
#    effective_lead_rating  fam_comm_ties_rating  trust_rating  ...  \
# ...

# %% [markdown]
# Data Frame should have the following:
# dbn / school_type / enrollment

# %%
df = dataFrame()
