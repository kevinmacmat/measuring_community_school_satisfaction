# %%
import pandas as pd

# %%
df = pd.read_csv('sqr_no_comments.csv')

# %%
df_1 = pd.read_csv('batch_0-100_comments.csv')

# %%
df_2 = pd.read_csv('batch_100-150_comments.csv')

# %%
df_3 = pd.read_csv('batch_150-200_comments.csv')

# %%
df_4 = pd.read_csv('batch_200-300_comments.csv')

# %%
df_5 = pd.read_csv('batch_300-400_comments.csv')

# %%
df_6 = pd.read_csv('batch_400-500_comments.csv')

# %%
df_7 = pd.read_csv('batch_500-600_comments.csv')

# %%
df_8 = pd.read_csv('batch_600-650_comments.csv')

# %%
df_9 = pd.read_csv('batch_650-700_comments.csv')

# %%
df_10 = pd.read_csv('batch_700-800_comments.csv')

# %%
df_11 = pd.read_csv('batch_800-900_comments.csv')

# %%
df_12 = pd.read_csv('batch_900-1000_comments.csv')

# %%
df_13 = pd.read_csv('batch_1000-end_comments.csv')

# %%
batch_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13], ignore_index = True)

# %%
df
# Out:
#          dbn                                    school_name school_type  \
# 0     01M015                      P.S. 015 Roberto Clemente  Elementary
# 1     01M019                            P.S. 019 Asher Levy  Elementary
# 2     01M020                           P.S. 020 Anna Silver  Elementary
# 3     01M034                 P.S. 034 Franklin D. Roosevelt         K-8
# 4     01M063                      The STAR Academy - P.S.63  Elementary
# ...      ...                                            ...         ...
# 1093  32K377             P.S. 377 Alejandrina B. De Gautier  Elementary
# 1094  32K383                   J.H.S. 383 Philippa Schuyler      Middle
# 1095  32K384               P.S. /I.S. 384 Frances E. Carter         K-8
# 1096  32K554           All City Leadership Secondary School      Middle
# 1097  32K562  Evergreen Middle School for Urban Exploration      Middle
#
#       fam_comm_ties_rating  trust_rating  pct_pos_fam_comm_ties  \
# ...

# %%
batch_df
# Out:
#          dbn                                           comments
# 0     01M015  ['P.S. 15 is an extraordinary small school tha...
# 1     01M019  ['Wrong person', "The negative comments don't ...
# 2     01M020  ['While we have always lived with the notion t...
# 3     01M034  ['The DOE has tabled a proposal to combine PS ...
# 4     01M063  ["This school is an amazing school because we ...
# ...      ...                                                ...
# 1093  32K377  ['Does anyone remember Mr. Corlito, 6th grade ...
# 1094  32K383  ['The District 32 Community Education Council ...
# 1095  32K384  ['P.S./I.S. 384 principal Phyllis Raulli said ...
# 1096  32K554  ['for the 7th graders are you required to wear...
# 1097  32K562  ["Subbed at this school Twice, admins are rude...
#
# [1098 rows x 2 columns]

# %%
df['comments'] = batch_df['comments']

# %%
df
# Out:
#          dbn                                    school_name school_type  \
# 0     01M015                      P.S. 015 Roberto Clemente  Elementary
# 1     01M019                            P.S. 019 Asher Levy  Elementary
# 2     01M020                           P.S. 020 Anna Silver  Elementary
# 3     01M034                 P.S. 034 Franklin D. Roosevelt         K-8
# 4     01M063                      The STAR Academy - P.S.63  Elementary
# ...      ...                                            ...         ...
# 1093  32K377             P.S. 377 Alejandrina B. De Gautier  Elementary
# 1094  32K383                   J.H.S. 383 Philippa Schuyler      Middle
# 1095  32K384               P.S. /I.S. 384 Frances E. Carter         K-8
# 1096  32K554           All City Leadership Secondary School      Middle
# 1097  32K562  Evergreen Middle School for Urban Exploration      Middle
#
#       fam_comm_ties_rating  trust_rating  pct_pos_fam_comm_ties  \
# ...

# %% [markdown]
# Pre-Process (stem/lemm, stop words, punctuation)
